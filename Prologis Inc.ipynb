# %%
import yfinance as yf
import pandas as pd

# %%
#Fetching 'Prologis Inc' data for the last 25 years

ticker_prologis = 'PLD'

data = yf.download(ticker_prologis, start = '2000-01-01', end = '2025-12-31')

print(data.head())

data.to_excel('pld.xlsx')
# Out:
# /tmp/ipykernel_264/2187375124.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker_prologis, start = '2000-01-01', end = '2025-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open  Volume
# Ticker           PLD       PLD       PLD       PLD     PLD
# Date
# 2000-01-03  7.423751  7.470588  7.400332  7.470588   36200
# 2000-01-04  7.306657  7.470588  7.119307  7.470588  148500
# 2000-01-05  7.212983  7.212983  7.049051  7.119308  178700
# 2000-01-06  7.353491  7.423748  7.259816  7.259816  452800
# 2000-01-07  7.494007  7.494007  7.400332  7.400332  290700
